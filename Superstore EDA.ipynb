# %%
# Importing neccesaries libraries 

#For reading data 
import pandas as pd 
#For visualization 
import matplotlib.pyplot as plt 
import seaborn as sns 
#For warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
#Lets read and explore the dataset 
data = pd.read_excel('Superstore - Sales.xlsx')
data.head()
# Out:
#    Row ID        Order ID           Order Date            Ship Date  \
# 0       1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1       2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2       3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3       4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4       5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
#
#         Ship Mode Customer ID        Country             City       State  \
# 0    Second Class    CG-12520  United States        Henderson    Kentucky
# 1    Second Class    CG-12520  United States        Henderson    Kentucky
# 2    Second Class    DV-13045  United States      Los Angeles  California
# 3  Standard Class    SO-20335  United States  Fort Lauderdale     Florida
# 4  Standard Class    SO-20335  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID     Sales  Quantity  Discount    Profit
# ...

# %%
data.describe().transpose()
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
#Checking the shape of data 
print(data.shape)
print('There are 9994 rows and 16 columns')
# Out:
# (9994, 16)
# There are 9994 rows and 16 columns

# %%
# Checking null values 
data.isnull().sum()
# Out:
# Row ID         0
# Order ID       0
# Order Date     0
# Ship Date      0
# Ship Mode      0
# Customer ID    0
# Country        0
# City           0
# State          0
# Postal Code    0
# Region         0
# Product ID     0
# Sales          0
# Quantity       0
# Discount       0
# Profit         0
# dtype: int64

# %%
print("There are no null values present in the dataset")
# Out:
# There are no null values present in the dataset

# %%
#Pairplot 

sns.pairplot(data)

# %%
#Correaltion
plt.figure(figsize=(15,8))
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # As you can see there is no strong correlation between features

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
sns.countplot(data,x='Region')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
# Sales in different region 
sns.barplot(data,x='Sales',y='Region')
# Out:
# <Axes: xlabel='Sales', ylabel='Region'>

# %%
data['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
#Checking Sales per city
plt.figure(figsize=(12,100))
sns.barplot(data,x='Sales',y='City')
plt.show()

# %%
data['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
#State Sales
plt.figure(figsize=(12,20))
sns.barplot(data,x='Sales',y='State')
plt.show()

# %%
df = pd.read_csv('Superstore - Sales_With Product Category and Sub-Category.csv')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky        42420  South
# 1  United States        Henderson    Kentucky        42420  South
# 2  United States      Los Angeles  California        90036   West
# 3  United States  Fort Lauderdale     Florida        33311  South
# 4  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID   Category     Sub-Category     Sales  Quantity  Discount  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=df,x='Category',y='Sales')
plt.show()

# %%
pie_chart=pd.DataFrame(df['Category'].value_counts())
plot = pie_chart.plot.pie(y='Category', figsize=(10, 10))

# %%
pie_=pd.DataFrame(df['Sub-Category'].value_counts())
plot = pie_.plot.pie(y='Sub-Category', figsize=(10, 10))

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=df,x='Ship Mode',y='Sales')
plt.show()
